# %%
# %matplotlib inline

from psrqpy import QueryATNF

import altair as alt
alt.renderers.enable('notebook')
# Out:
# ...
# RendererRegistry.enable('notebook')

# %%
#query = QueryATNF(params=['P0', 'P1'], condition='P1 > 0.')
query = QueryATNF(loadfromfile='p0p1.pkl')

# %%
chart = query.plot('P0', 'P1', logx=True, logy=True, usealtair=True)

# %%
#text = alt.TextConfig(font='Helvetica')
#chart.configure(text=text)
chart.interactive()
# Out:
# <div class="vega-embed" id="3e776815-066c-47f6-a300-e3e34c0c33fb"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %%
query.save('p0p1.pkl')

# %%
query.pandas()['JNAME'][0]
# Out:
# 'J0002+6216'
