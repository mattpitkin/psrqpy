# %%
# %matplotlib inline

import psrqpy

# %%
q = psrqpy.QueryATNF(params=['P0', 'P1', 'ASSOC', 'BINARY', 'TYPE', 'P1_I'])

# %%
fig = q.ppdot(showSNRs=True, showtypes='all')

# %%
fig.savefig('ppdot.png')
